# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
from colors_labels import *
from utils import *
import random

# %%
segmentations_path = './segmentations'
val_segmen_path = os.path.join(segmentations_path, 'val')
val_path = os.path.join('./val_test2020', 'test')

val_images = os.listdir(val_segmen_path)

index = random.randint(0, len(val_segmen_path)-1)
name = val_images[index]

seg_name = name
img_name = f'{name[:-8]}.jpg'

seg_path = os.path.join(val_segmen_path, seg_name)
image_path = os.path.join(val_path, img_name)

# %%
segmentation = cv2.imread(seg_path)
segmentation = cv2.cvtColor(segmentation, cv2.COLOR_RGB2GRAY)
print(np.unique(segmentation))
segmentation = cv2.resize(segmentation, (500, 500), interpolation=cv2.INTER_NEAREST)
print(np.unique(segmentation))

image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (500, 500))
# Out:
# [ 0  1  8 19 24 30 32 33 36 43]
# [ 0  1  8 19 24 30 32 33 36 43]

# %%
plot_segmentation(image, segmentation, segmentation, './', 'test')
